# %% [markdown]
# # AeroSynth-Eval — Qwen2.5-VL-3B on a free Colab GPU
# Runs the frozen 12-case development queue. It does not touch the protected test set.

# %%
import subprocess
gpu = subprocess.check_output(
    ['nvidia-smi', '--query-gpu=name,memory.total', '--format=csv,noheader'],
    text=True,
).strip()
print('GPU:', gpu)
# Out:
# GPU: Tesla T4, 15360 MiB

# %%
import json
import subprocess
from pathlib import Path

ROOT = Path('/content/AeroSynth-Eval')
subprocess.run(['git', 'fetch', 'origin', 'fix/kaggle-p100-pascal'], cwd=ROOT, check=True)
subprocess.run(['git', 'reset', '--hard', 'origin/fix/kaggle-p100-pascal'], cwd=ROOT, check=True)
OUTPUT = ROOT / 'reports/qwen25_vl_3b_defect_sensitive_development.json'
if OUTPUT.exists():
    OUTPUT.unlink()
subprocess.run([
    'python', 'scripts/run_qwen25_vl.py',
    '--prompt-style', 'defect_sensitive',
    '--output', str(OUTPUT),
], cwd=ROOT, check=True)
payload = json.loads(OUTPUT.read_text())
print(json.dumps({
    'model_id': payload['model_id'],
    'prompt_style': payload['prompt_style'],
    'case_count': payload['case_count'],
import json
import subprocess
from pathlib import Path

ROOT = Path('/content/AeroSynth-Eval')
subprocess.run(['git', 'fetch', 'origin', 'fix/kaggle-p100-pascal'], cwd=ROOT, check=True)
subprocess.run(['git', 'reset', '--hard', 'origin/fix/kaggle-p100-pascal'], cwd=ROOT, check=True)
OUTPUT = ROOT / 'reports/qwen25_vl_3b_defect_sensitive_development.json'
if OUTPUT.exists():
    OUTPUT.unlink()
subprocess.run([
    'python', 'scripts/run_qwen25_vl.py',
    '--prompt-style', 'defect_sensitive',
    '--output', str(OUTPUT),
], cwd=ROOT, check=True)
payload = json.loads(OUTPUT.read_text())
print(json.dumps({
    'model_id': payload['model_id'],
    'prompt_style': payload['prompt_style'],
    'case_count': payload['case_count'],
    'parse_rate': payload['parse_rate'],
    'accuracy': payload['accuracy'],
    'mean_latency_ms': payload['mean_latency_ms'],
}, indent=2))
from google.colab import files
files.download(str(OUTPUT))
        'git', 'clone', '--branch', 'fix/kaggle-p100-pascal',
        'https://github.com/triasha72/AeroSynth-Eval.git', str(ROOT),
    ], check=True)
else:
    subprocess.run(['git', 'fetch', 'origin', 'fix/kaggle-p100-pascal'], cwd=ROOT, check=True)
    subprocess.run(['git', 'reset', '--hard', 'origin/fix/kaggle-p100-pascal'], cwd=ROOT, check=True)
subprocess.run([
    'python', '-m', 'pip', 'install', '-q',
    'transformers>=4.50,<5', 'accelerate', 'qwen-vl-utils', 'torch', 'torchvision',
], check=True)
# Out:
# CompletedProcess(args=['python', '-m', 'pip', 'install', '-q', 'transformers>=4.50,<5', 'accelerate', 'qwen-vl-utils', 'torch', 'torchvision'], returncode=0)

# %%
OUTPUT = ROOT / 'reports/qwen25_vl_3b_development.json'
if OUTPUT.exists():
    OUTPUT.unlink()
subprocess.run([
    'python', 'scripts/run_qwen25_vl.py', '--output', str(OUTPUT),
], cwd=ROOT, check=True)
# Out:
# CompletedProcess(args=['python', 'scripts/run_qwen25_vl.py', '--output', '/content/AeroSynth-Eval/reports/qwen25_vl_3b_development.json'], returncode=0)

# %%
import hashlib, json
payload = json.loads(OUTPUT.read_text())
summary = {key: payload[key] for key in [
    'model_id', 'device', 'case_count', 'parse_rate', 'accuracy', 'mean_latency_ms'
]}
summary['sha256'] = hashlib.sha256(OUTPUT.read_bytes()).hexdigest()
print(json.dumps(summary, indent=2))
from google.colab import files
files.download(str(OUTPUT))
# Out:
# {
#   "model_id": "Qwen/Qwen2.5-VL-3B-Instruct",
#   "device": "cuda",
#   "case_count": 12,
#   "parse_rate": 1.0,
#   "accuracy": 0.3333333333333333,
#   "mean_latency_ms": 1246.3067973333418,
#   "sha256": "420553c19d7a716135f58893d4897e3e73a915b924afb8d3f6cdc4ecef8bb1c4"
# }
